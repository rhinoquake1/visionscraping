# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = r'https://www.visiondirect.co.uk/1-day-acuvue-moist'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html lang="en" id="top" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="en" id="top" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="en" id="top" class="no-js ie8"> <![endif]-->
# <!--[if IE 9 ]>    <html lang="en" id="top" class="no-js ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" id="top" lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>1 Day Acuvue Moist Contact Lenses  | Vision Direct UK</title>
# <meta content="Buy 1 Day Acuvue Moist Daily Contact Lenses online. Next day delivery, LOWEST prices &amp; FREE 365-day returns guarantee. Daily contact lenses for dry eyes." name="description"/>
# <meta content="" name="keywords"/>
# <meta content="noodp, noydir" name="robots"/>
# <!--<meta name="viewport" content="initial-scale=1.0, width=device-width">-->
# ...

# %%
def preptext(val):
    if val != None:
        return val.text.strip()

# %%
product = soup.find('h1').text.strip()
product
# Out:
# '1 Day Acuvue Moist'

# %%
manufacturer = soup.find('div', class_='manufacturer').find('span').text.strip()
manufacturer
# Out:
# 'Johnson & Johnson'

# %%
pricing_info = soup.find('tr', class_='cart-price-item')
price_type = pricing_info.select('td[colspan="1"]')[0].text.strip()
price = pricing_info.find(id='price-per-box').text.strip()
other_price = pricing_info.find(class_='price theirs price--hs')
other_price = preptext(other_price)

# %%
soup.find('div', class_='selectric-scroll')

# %%
class SiteMethods:
    def __init__(self):
        pass

    class visiondirect:
        def __init__(self):
            pass
